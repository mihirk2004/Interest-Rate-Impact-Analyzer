# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import r2_score, mean_squared_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.models import save_model
import joblib

# Load and preprocess data
df = pd.read_csv('Interest Rate and Economic Growth Rate.csv', parse_dates=['Date'])
df.sort_values('Date', inplace=True)

# Feature engineering: Add moving averages
window_size = 5
df['Interest_MA'] = df['Interest Rate'].rolling(window=window_size).mean()
df['Growth_MA'] = df['Economic Growth Rate'].rolling(window=window_size).mean()
df.dropna(inplace=True)

# In your original training script, modify this section:

# Normalize data
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(df[['Interest Rate', 'Economic Growth Rate', 'Interest_MA', 'Growth_MA']])

# Add this line to save the scaler
joblib.dump(scaler, 'scaler.pkl')  # <-- Add this line

# Create sequences with multiple features
def create_sequences(data, look_back=10):
    X, y = [], []
    for i in range(len(data)-look_back):
        X.append(data[i:(i+look_back), :2])  # Use both interest rate and growth rate
        y.append(data[i+look_back, 1])       # Predict growth rate
    return np.array(X), np.array(y)

look_back = 10  # Increased window size
X, y = create_sequences(scaled_data, look_back)

# Split into train/test sets
train_size = int(len(X) * 0.8)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# Build enhanced LSTM model
model = Sequential([
    LSTM(128, return_sequences=True, input_shape=(look_back, 2)),
    BatchNormalization(),
    Dropout(0.3),
    LSTM(64, return_sequences=True),
    BatchNormalization(),
    Dropout(0.3),
    LSTM(32),
    BatchNormalization(),
    Dropout(0.2),
    Dense(32, activation='relu', kernel_regularizer='l2'),
    Dense(1)
])

optimizer = Adam(learning_rate=0.001)
model.compile(optimizer=optimizer, loss='mse', metrics=['mae'])

# Add callbacks
callbacks = [
    EarlyStopping(patience=20, restore_best_weights=True),
    ReduceLROnPlateau(factor=0.5, patience=10)
]

# Train model with more epochs
history = model.fit(X_train, y_train,
                    epochs=300,
                    batch_size=64,
                    validation_split=0.2,
                    callbacks=callbacks,
                    verbose=1)

# Save model
save_model(model, 'improved_economic_growth_lstm.keras')
# joblib.dump(scaler, 'scaler.pkl')

# Make predictions
train_predict = model.predict(X_train)
test_predict = model.predict(X_test)

# Inverse scaling
def inverse_scale(y, scaler, feature_pos=1):
    dummy = np.zeros((len(y), scaled_data.shape[1]))
    dummy[:, feature_pos] = y.reshape(-1)
    return scaler.inverse_transform(dummy)[:, feature_pos]

y_train_actual = inverse_scale(y_train, scaler)
y_test_actual = inverse_scale(y_test, scaler)
train_predict = inverse_scale(train_predict, scaler)
test_predict = inverse_scale(test_predict, scaler)

# Calculate metrics
train_r2 = r2_score(y_train_actual, train_predict)
test_r2 = r2_score(y_test_actual, test_predict)
train_rmse = np.sqrt(mean_squared_error(y_train_actual, train_predict))
test_rmse = np.sqrt(mean_squared_error(y_test_actual, test_predict))

print(f"Train R²: {train_r2:.4f}, Test R²: {test_r2:.4f}")
print(f"Train RMSE: {train_rmse:.4f}, Test RMSE: {test_rmse:.4f}")


# Enhanced visualization
total_samples = len(X)  # This matches y_train_actual + y_test_actual
start_index = look_back  # First valid index after sequence creation

# Create date range for predictions
prediction_dates = df['Date'].iloc[start_index:start_index+total_samples]

plt.figure(figsize=(16, 8))
plt.plot(prediction_dates, np.concatenate([y_train_actual, y_test_actual]), 
         label='Actual Values', color='blue', alpha=0.6)

# Plot predictions
plt.plot(prediction_dates[:len(y_train_actual)], train_predict, 
         label='Train Predictions', color='red', linestyle='--')
plt.plot(prediction_dates[len(y_train_actual):], test_predict,
         label='Test Predictions', color='orange', linestyle='--')

plt.title(f'Economic Growth Rate Predictions\nTest R²: {test_r2:.2f}, Test RMSE: {test_rmse:.2f}')
plt.ylabel('Economic Growth Rate')
plt.xlabel('Date')
plt.legend()
plt.grid(True)
plt.show()

# Feature importance analysis
plt.figure(figsize=(8, 4))
plt.bar(['Interest Rate', 'Economic Growth Rate'],
        np.abs(model.layers[0].get_weights()[0]).mean(axis=1))
plt.title('Input Feature Importance (First LSTM Layer Weights)')
plt.ylabel('Average Weight Magnitude')
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_3844\1896302937.py:14: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df = pd.read_csv('Interest Rate and Economic Growth Rate.csv', parse_dates=['Date'])
# c:\Users\Admin\Documents\Mihir Codes\Sem 4\AI Assignments\AI PBL\aipblenv\lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 10s 97ms/step - loss: 3.3799 - mae: 1.5167 - val_loss: 0.8708 - val_mae: 0.7375 - learning_rate: 0.0010
# Epoch 2/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.7004 - mae: 0.4834 - val_loss: 0.7428 - val_mae: 0.6529 - learning_rate: 0.0010
# Epoch 3/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.5436 - mae: 0.3805 - val_loss: 0.7085 - val_mae: 0.6340 - learning_rate: 0.0010
# Epoch 4/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.5009 - mae: 0.3539 - val_loss: 0.6732 - val_mae: 0.6134 - learning_rate: 0.0010
# Epoch 5/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.4436 - mae: 0.3040 - val_loss: 0.6562 - val_mae: 0.6070 - learning_rate: 0.0010
# Epoch 6/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.4238 - mae: 0.2981 - val_loss: 0.6727 - val_mae: 0.6265 - learning_rate: 0.0010
# Epoch 7/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - loss: 0.3753 - mae: 0.2531 - val_loss: 0.6118 - val_mae: 0.5825 - learning_rate: 0.0010
# Epoch 8/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.3602 - mae: 0.2397 - val_loss: 0.5806 - val_mae: 0.5607 - learning_rate: 0.0010
# Epoch 9/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.3421 - mae: 0.2299 - val_loss: 0.5228 - val_mae: 0.5140 - learning_rate: 0.0010
# Epoch 10/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.3217 - mae: 0.2169 - val_loss: 0.4791 - val_mae: 0.4773 - learning_rate: 0.0010
# Epoch 11/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.3113 - mae: 0.2145 - val_loss: 0.3992 - val_mae: 0.3964 - learning_rate: 0.0010
# Epoch 12/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - loss: 0.2929 - mae: 0.1941 - val_loss: 0.3509 - val_mae: 0.3351 - learning_rate: 0.0010
# Epoch 13/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - loss: 0.2736 - mae: 0.1741 - val_loss: 0.2989 - val_mae: 0.2590 - learning_rate: 0.0010
# Epoch 14/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.2656 - mae: 0.1761 - val_loss: 0.2786 - val_mae: 0.2241 - learning_rate: 0.0010
# Epoch 15/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.2537 - mae: 0.1672 - val_loss: 0.2508 - val_mae: 0.1838 - learning_rate: 0.0010
# Epoch 16/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.2434 - mae: 0.1597 - val_loss: 0.2232 - val_mae: 0.1381 - learning_rate: 0.0010
# Epoch 17/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.2315 - mae: 0.1500 - val_loss: 0.2037 - val_mae: 0.1007 - learning_rate: 0.0010
# Epoch 18/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.2189 - mae: 0.1379 - val_loss: 0.1909 - val_mae: 0.0714 - learning_rate: 0.0010
# Epoch 19/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.2088 - mae: 0.1288 - val_loss: 0.1816 - val_mae: 0.0473 - learning_rate: 0.0010
# Epoch 20/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.2020 - mae: 0.1287 - val_loss: 0.1747 - val_mae: 0.0445 - learning_rate: 0.0010
# Epoch 21/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.1945 - mae: 0.1213 - val_loss: 0.1683 - val_mae: 0.0443 - learning_rate: 0.0010
# Epoch 22/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.1889 - mae: 0.1228 - val_loss: 0.1613 - val_mae: 0.0299 - learning_rate: 0.0010
# Epoch 23/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.1797 - mae: 0.1142 - val_loss: 0.1568 - val_mae: 0.0361 - learning_rate: 0.0010
# Epoch 24/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.1753 - mae: 0.1167 - val_loss: 0.1532 - val_mae: 0.0503 - learning_rate: 0.0010
# Epoch 25/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.1656 - mae: 0.1073 - val_loss: 0.1457 - val_mae: 0.0355 - learning_rate: 0.0010
# Epoch 26/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.1610 - mae: 0.1059 - val_loss: 0.1405 - val_mae: 0.0326 - learning_rate: 0.0010
# Epoch 27/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.1525 - mae: 0.0974 - val_loss: 0.1363 - val_mae: 0.0382 - learning_rate: 0.0010
# Epoch 28/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.1482 - mae: 0.0974 - val_loss: 0.1299 - val_mae: 0.0245 - learning_rate: 0.0010
# Epoch 29/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.1421 - mae: 0.0944 - val_loss: 0.1264 - val_mae: 0.0317 - learning_rate: 0.0010
# Epoch 30/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.1354 - mae: 0.0861 - val_loss: 0.1233 - val_mae: 0.0410 - learning_rate: 0.0010
# Epoch 31/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.1326 - mae: 0.0930 - val_loss: 0.1213 - val_mae: 0.0546 - learning_rate: 0.0010
# Epoch 32/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.1266 - mae: 0.0859 - val_loss: 0.1143 - val_mae: 0.0427 - learning_rate: 0.0010
# Epoch 33/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.1219 - mae: 0.0841 - val_loss: 0.1120 - val_mae: 0.0587 - learning_rate: 0.0010
# Epoch 34/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.1171 - mae: 0.0803 - val_loss: 0.1076 - val_mae: 0.0480 - learning_rate: 0.0010
# Epoch 35/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.1127 - mae: 0.0819 - val_loss: 0.1025 - val_mae: 0.0419 - learning_rate: 0.0010
# Epoch 36/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.1091 - mae: 0.0816 - val_loss: 0.1020 - val_mae: 0.0673 - learning_rate: 0.0010
# Epoch 37/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.1035 - mae: 0.0719 - val_loss: 0.0982 - val_mae: 0.0709 - learning_rate: 0.0010
# Epoch 38/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0992 - mae: 0.0688 - val_loss: 0.0920 - val_mae: 0.0515 - learning_rate: 0.0010
# Epoch 39/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0974 - mae: 0.0761 - val_loss: 0.0867 - val_mae: 0.0303 - learning_rate: 0.0010
# Epoch 40/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0930 - mae: 0.0737 - val_loss: 0.0852 - val_mae: 0.0478 - learning_rate: 0.0010
# Epoch 41/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0903 - mae: 0.0745 - val_loss: 0.0819 - val_mae: 0.0486 - learning_rate: 0.0010
# Epoch 42/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0865 - mae: 0.0735 - val_loss: 0.0784 - val_mae: 0.0429 - learning_rate: 0.0010
# Epoch 43/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0829 - mae: 0.0695 - val_loss: 0.0778 - val_mae: 0.0584 - learning_rate: 0.0010
# Epoch 44/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0789 - mae: 0.0631 - val_loss: 0.0748 - val_mae: 0.0584 - learning_rate: 0.0010
# Epoch 45/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 0.0759 - mae: 0.0642 - val_loss: 0.0769 - val_mae: 0.0855 - learning_rate: 0.0010
# Epoch 46/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0735 - mae: 0.0642 - val_loss: 0.0712 - val_mae: 0.0731 - learning_rate: 0.0010
# Epoch 47/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0703 - mae: 0.0605 - val_loss: 0.0664 - val_mae: 0.0608 - learning_rate: 0.0010
# Epoch 48/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0671 - mae: 0.0598 - val_loss: 0.0611 - val_mae: 0.0318 - learning_rate: 0.0010
# Epoch 49/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0646 - mae: 0.0588 - val_loss: 0.0603 - val_mae: 0.0477 - learning_rate: 0.0010
# Epoch 50/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0623 - mae: 0.0590 - val_loss: 0.0569 - val_mae: 0.0380 - learning_rate: 0.0010
# Epoch 51/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0594 - mae: 0.0560 - val_loss: 0.0547 - val_mae: 0.0389 - learning_rate: 0.0010
# Epoch 52/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0569 - mae: 0.0533 - val_loss: 0.0531 - val_mae: 0.0446 - learning_rate: 0.0010
# Epoch 53/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.0547 - mae: 0.0538 - val_loss: 0.0498 - val_mae: 0.0315 - learning_rate: 0.0010
# Epoch 54/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0520 - mae: 0.0503 - val_loss: 0.0486 - val_mae: 0.0415 - learning_rate: 0.0010
# Epoch 55/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0502 - mae: 0.0508 - val_loss: 0.0458 - val_mae: 0.0293 - learning_rate: 0.0010
# Epoch 56/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 0.0487 - mae: 0.0539 - val_loss: 0.0453 - val_mae: 0.0490 - learning_rate: 0.0010
# Epoch 57/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0466 - mae: 0.0527 - val_loss: 0.0448 - val_mae: 0.0607 - learning_rate: 0.0010
# Epoch 58/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0447 - mae: 0.0514 - val_loss: 0.0412 - val_mae: 0.0426 - learning_rate: 0.0010
# Epoch 59/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0435 - mae: 0.0565 - val_loss: 0.0421 - val_mae: 0.0655 - learning_rate: 0.0010
# Epoch 60/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0420 - mae: 0.0560 - val_loss: 0.0385 - val_mae: 0.0468 - learning_rate: 0.0010
# Epoch 61/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0396 - mae: 0.0517 - val_loss: 0.0356 - val_mae: 0.0326 - learning_rate: 0.0010
# Epoch 62/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0371 - mae: 0.0458 - val_loss: 0.0335 - val_mae: 0.0258 - learning_rate: 0.0010
# Epoch 63/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - loss: 0.0359 - mae: 0.0469 - val_loss: 0.0320 - val_mae: 0.0224 - learning_rate: 0.0010
# Epoch 64/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0353 - mae: 0.0531 - val_loss: 0.0311 - val_mae: 0.0293 - learning_rate: 0.0010
# Epoch 65/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 0.0329 - mae: 0.0455 - val_loss: 0.0299 - val_mae: 0.0321 - learning_rate: 0.0010
# Epoch 66/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0315 - mae: 0.0430 - val_loss: 0.0286 - val_mae: 0.0307 - learning_rate: 0.0010
# Epoch 67/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0299 - mae: 0.0424 - val_loss: 0.0281 - val_mae: 0.0412 - learning_rate: 0.0010
# Epoch 68/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0291 - mae: 0.0451 - val_loss: 0.0263 - val_mae: 0.0338 - learning_rate: 0.0010
# Epoch 69/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0274 - mae: 0.0414 - val_loss: 0.0257 - val_mae: 0.0407 - learning_rate: 0.0010
# Epoch 70/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0265 - mae: 0.0441 - val_loss: 0.0260 - val_mae: 0.0530 - learning_rate: 0.0010
# Epoch 71/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.0257 - mae: 0.0454 - val_loss: 0.0234 - val_mae: 0.0392 - learning_rate: 0.0010
# Epoch 72/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0242 - mae: 0.0418 - val_loss: 0.0222 - val_mae: 0.0362 - learning_rate: 0.0010
# Epoch 73/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.0232 - mae: 0.0417 - val_loss: 0.0207 - val_mae: 0.0289 - learning_rate: 0.0010
# Epoch 74/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0219 - mae: 0.0393 - val_loss: 0.0193 - val_mae: 0.0201 - learning_rate: 0.0010
# Epoch 75/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0213 - mae: 0.0418 - val_loss: 0.0183 - val_mae: 0.0196 - learning_rate: 0.0010
# Epoch 76/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0199 - mae: 0.0372 - val_loss: 0.0177 - val_mae: 0.0239 - learning_rate: 0.0010
# Epoch 77/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0190 - mae: 0.0373 - val_loss: 0.0170 - val_mae: 0.0261 - learning_rate: 0.0010
# Epoch 78/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0183 - mae: 0.0381 - val_loss: 0.0160 - val_mae: 0.0212 - learning_rate: 0.0010
# Epoch 79/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.0174 - mae: 0.0361 - val_loss: 0.0152 - val_mae: 0.0217 - learning_rate: 0.0010
# Epoch 80/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.0165 - mae: 0.0351 - val_loss: 0.0150 - val_mae: 0.0287 - learning_rate: 0.0010
# Epoch 81/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - loss: 0.0155 - mae: 0.0331 - val_loss: 0.0143 - val_mae: 0.0297 - learning_rate: 0.0010
# Epoch 82/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0150 - mae: 0.0342 - val_loss: 0.0139 - val_mae: 0.0312 - learning_rate: 0.0010
# Epoch 83/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0142 - mae: 0.0334 - val_loss: 0.0131 - val_mae: 0.0303 - learning_rate: 0.0010
# Epoch 84/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.0135 - mae: 0.0319 - val_loss: 0.0127 - val_mae: 0.0334 - learning_rate: 0.0010
# Epoch 85/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0132 - mae: 0.0346 - val_loss: 0.0122 - val_mae: 0.0343 - learning_rate: 0.0010
# Epoch 86/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0125 - mae: 0.0331 - val_loss: 0.0128 - val_mae: 0.0474 - learning_rate: 0.0010
# Epoch 87/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0125 - mae: 0.0388 - val_loss: 0.0132 - val_mae: 0.0549 - learning_rate: 0.0010
# Epoch 88/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.0116 - mae: 0.0353 - val_loss: 0.0112 - val_mae: 0.0403 - learning_rate: 0.0010
# Epoch 89/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0109 - mae: 0.0332 - val_loss: 0.0095 - val_mae: 0.0245 - learning_rate: 0.0010
# Epoch 90/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0104 - mae: 0.0331 - val_loss: 0.0093 - val_mae: 0.0281 - learning_rate: 0.0010
# Epoch 91/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0096 - mae: 0.0294 - val_loss: 0.0097 - val_mae: 0.0379 - learning_rate: 0.0010
# Epoch 92/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 0.0095 - mae: 0.0325 - val_loss: 0.0081 - val_mae: 0.0220 - learning_rate: 0.0010
# Epoch 93/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 0.0088 - mae: 0.0308 - val_loss: 0.0086 - val_mae: 0.0347 - learning_rate: 0.0010
# Epoch 94/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - loss: 0.0084 - mae: 0.0289 - val_loss: 0.0090 - val_mae: 0.0449 - learning_rate: 0.0010
# Epoch 95/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0080 - mae: 0.0302 - val_loss: 0.0080 - val_mae: 0.0378 - learning_rate: 0.0010
# Epoch 96/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0079 - mae: 0.0323 - val_loss: 0.0072 - val_mae: 0.0313 - learning_rate: 0.0010
# Epoch 97/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0071 - mae: 0.0266 - val_loss: 0.0081 - val_mae: 0.0462 - learning_rate: 0.0010
# Epoch 98/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - loss: 0.0070 - mae: 0.0292 - val_loss: 0.0070 - val_mae: 0.0359 - learning_rate: 0.0010
# Epoch 99/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0065 - mae: 0.0271 - val_loss: 0.0064 - val_mae: 0.0333 - learning_rate: 0.0010
# Epoch 100/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.0063 - mae: 0.0283 - val_loss: 0.0071 - val_mae: 0.0431 - learning_rate: 0.0010
# Epoch 101/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0060 - mae: 0.0273 - val_loss: 0.0069 - val_mae: 0.0429 - learning_rate: 0.0010
# Epoch 102/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0056 - mae: 0.0257 - val_loss: 0.0056 - val_mae: 0.0310 - learning_rate: 0.0010
# Epoch 103/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0054 - mae: 0.0276 - val_loss: 0.0062 - val_mae: 0.0416 - learning_rate: 0.0010
# Epoch 104/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0050 - mae: 0.0255 - val_loss: 0.0053 - val_mae: 0.0335 - learning_rate: 0.0010
# Epoch 105/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0049 - mae: 0.0263 - val_loss: 0.0049 - val_mae: 0.0299 - learning_rate: 0.0010
# Epoch 106/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0046 - mae: 0.0248 - val_loss: 0.0051 - val_mae: 0.0354 - learning_rate: 0.0010
# Epoch 107/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0044 - mae: 0.0247 - val_loss: 0.0065 - val_mae: 0.0503 - learning_rate: 0.0010
# Epoch 108/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.0041 - mae: 0.0228 - val_loss: 0.0054 - val_mae: 0.0419 - learning_rate: 0.0010
# Epoch 109/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0040 - mae: 0.0245 - val_loss: 0.0038 - val_mae: 0.0223 - learning_rate: 0.0010
# Epoch 110/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0037 - mae: 0.0229 - val_loss: 0.0045 - val_mae: 0.0344 - learning_rate: 0.0010
# Epoch 111/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0037 - mae: 0.0250 - val_loss: 0.0040 - val_mae: 0.0296 - learning_rate: 0.0010
# Epoch 112/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0034 - mae: 0.0227 - val_loss: 0.0046 - val_mae: 0.0390 - learning_rate: 0.0010
# Epoch 113/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0035 - mae: 0.0267 - val_loss: 0.0033 - val_mae: 0.0260 - learning_rate: 0.0010
# Epoch 114/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0034 - mae: 0.0275 - val_loss: 0.0049 - val_mae: 0.0462 - learning_rate: 0.0010
# Epoch 115/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0031 - mae: 0.0253 - val_loss: 0.0056 - val_mae: 0.0503 - learning_rate: 0.0010
# Epoch 116/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0028 - mae: 0.0220 - val_loss: 0.0029 - val_mae: 0.0245 - learning_rate: 0.0010
# Epoch 117/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0026 - mae: 0.0209 - val_loss: 0.0045 - val_mae: 0.0430 - learning_rate: 0.0010
# Epoch 118/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - loss: 0.0026 - mae: 0.0229 - val_loss: 0.0035 - val_mae: 0.0337 - learning_rate: 0.0010
# Epoch 119/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0023 - mae: 0.0192 - val_loss: 0.0034 - val_mae: 0.0350 - learning_rate: 0.0010
# Epoch 120/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0024 - mae: 0.0220 - val_loss: 0.0040 - val_mae: 0.0420 - learning_rate: 0.0010
# Epoch 121/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0023 - mae: 0.0218 - val_loss: 0.0030 - val_mae: 0.0330 - learning_rate: 0.0010
# Epoch 122/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.0023 - mae: 0.0228 - val_loss: 0.0027 - val_mae: 0.0302 - learning_rate: 0.0010
# Epoch 123/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0020 - mae: 0.0202 - val_loss: 0.0025 - val_mae: 0.0285 - learning_rate: 0.0010
# Epoch 124/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0019 - mae: 0.0204 - val_loss: 0.0020 - val_mae: 0.0226 - learning_rate: 0.0010
# Epoch 125/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0019 - mae: 0.0216 - val_loss: 0.0028 - val_mae: 0.0352 - learning_rate: 0.0010
# Epoch 126/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0018 - mae: 0.0201 - val_loss: 0.0031 - val_mae: 0.0386 - learning_rate: 0.0010
# Epoch 127/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0019 - mae: 0.0230 - val_loss: 0.0022 - val_mae: 0.0296 - learning_rate: 0.0010
# Epoch 128/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.0015 - mae: 0.0181 - val_loss: 0.0020 - val_mae: 0.0282 - learning_rate: 0.0010
# Epoch 129/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.0016 - mae: 0.0208 - val_loss: 0.0016 - val_mae: 0.0232 - learning_rate: 0.0010
# Epoch 130/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0015 - mae: 0.0199 - val_loss: 0.0020 - val_mae: 0.0293 - learning_rate: 0.0010
# Epoch 131/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.0015 - mae: 0.0215 - val_loss: 0.0025 - val_mae: 0.0373 - learning_rate: 0.0010
# Epoch 132/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - loss: 0.0014 - mae: 0.0201 - val_loss: 0.0015 - val_mae: 0.0248 - learning_rate: 0.0010
# Epoch 133/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.0012 - mae: 0.0182 - val_loss: 0.0015 - val_mae: 0.0247 - learning_rate: 0.0010
# Epoch 134/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0012 - mae: 0.0179 - val_loss: 0.0012 - val_mae: 0.0208 - learning_rate: 0.0010
# Epoch 135/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0012 - mae: 0.0178 - val_loss: 0.0013 - val_mae: 0.0228 - learning_rate: 0.0010
# Epoch 136/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0011 - mae: 0.0181 - val_loss: 0.0013 - val_mae: 0.0232 - learning_rate: 0.0010
# Epoch 137/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0011 - mae: 0.0176 - val_loss: 0.0012 - val_mae: 0.0245 - learning_rate: 0.0010
# Epoch 138/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0010 - mae: 0.0176 - val_loss: 0.0016 - val_mae: 0.0297 - learning_rate: 0.0010
# Epoch 139/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0010 - mae: 0.0177 - val_loss: 9.8622e-04 - val_mae: 0.0194 - learning_rate: 0.0010
# Epoch 140/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0010 - mae: 0.0185 - val_loss: 0.0012 - val_mae: 0.0266 - learning_rate: 0.0010
# Epoch 141/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0010 - mae: 0.0190 - val_loss: 0.0013 - val_mae: 0.0267 - learning_rate: 0.0010
# Epoch 142/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 9.0938e-04 - mae: 0.0177 - val_loss: 0.0014 - val_mae: 0.0289 - learning_rate: 0.0010
# Epoch 143/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 9.6211e-04 - mae: 0.0195 - val_loss: 0.0019 - val_mae: 0.0350 - learning_rate: 0.0010
# Epoch 144/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 8.0014e-04 - mae: 0.0166 - val_loss: 0.0011 - val_mae: 0.0258 - learning_rate: 0.0010
# Epoch 145/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 7.6491e-04 - mae: 0.0162 - val_loss: 0.0011 - val_mae: 0.0235 - learning_rate: 0.0010
# Epoch 146/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - loss: 8.5813e-04 - mae: 0.0180 - val_loss: 0.0013 - val_mae: 0.0293 - learning_rate: 0.0010
# Epoch 147/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 8.0853e-04 - mae: 0.0171 - val_loss: 0.0011 - val_mae: 0.0263 - learning_rate: 0.0010
# Epoch 148/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 7.2200e-04 - mae: 0.0161 - val_loss: 6.4753e-04 - val_mae: 0.0171 - learning_rate: 0.0010
# Epoch 149/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 7.3009e-04 - mae: 0.0161 - val_loss: 0.0012 - val_mae: 0.0276 - learning_rate: 0.0010
# Epoch 150/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 6.4834e-04 - mae: 0.0156 - val_loss: 0.0018 - val_mae: 0.0362 - learning_rate: 0.0010
# Epoch 151/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 7.1135e-04 - mae: 0.0166 - val_loss: 0.0023 - val_mae: 0.0409 - learning_rate: 0.0010
# Epoch 152/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 6.9138e-04 - mae: 0.0168 - val_loss: 0.0012 - val_mae: 0.0274 - learning_rate: 0.0010
# Epoch 153/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 6.0480e-04 - mae: 0.0147 - val_loss: 0.0011 - val_mae: 0.0261 - learning_rate: 0.0010
# Epoch 154/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 7.5304e-04 - mae: 0.0179 - val_loss: 0.0012 - val_mae: 0.0283 - learning_rate: 0.0010
# Epoch 155/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 6.2582e-04 - mae: 0.0159 - val_loss: 9.0337e-04 - val_mae: 0.0247 - learning_rate: 0.0010
# Epoch 156/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 5.8463e-04 - mae: 0.0150 - val_loss: 5.9947e-04 - val_mae: 0.0185 - learning_rate: 0.0010
# Epoch 157/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 7.0963e-04 - mae: 0.0174 - val_loss: 4.4866e-04 - val_mae: 0.0142 - learning_rate: 0.0010
# Epoch 158/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 6.3589e-04 - mae: 0.0165 - val_loss: 5.4390e-04 - val_mae: 0.0157 - learning_rate: 0.0010
# Epoch 159/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 6.3757e-04 - mae: 0.0160 - val_loss: 0.0014 - val_mae: 0.0307 - learning_rate: 0.0010
# Epoch 160/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 9.2021e-04 - mae: 0.0212 - val_loss: 0.0010 - val_mae: 0.0272 - learning_rate: 0.0010
# Epoch 161/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 5.7655e-04 - mae: 0.0159 - val_loss: 6.0850e-04 - val_mae: 0.0176 - learning_rate: 0.0010
# Epoch 162/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 6.0811e-04 - mae: 0.0164 - val_loss: 8.6139e-04 - val_mae: 0.0233 - learning_rate: 0.0010
# Epoch 163/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 6.2923e-04 - mae: 0.0166 - val_loss: 0.0014 - val_mae: 0.0309 - learning_rate: 0.0010
# Epoch 164/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 4.7318e-04 - mae: 0.0139 - val_loss: 0.0010 - val_mae: 0.0264 - learning_rate: 0.0010
# Epoch 165/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 5.4296e-04 - mae: 0.0149 - val_loss: 7.0795e-04 - val_mae: 0.0210 - learning_rate: 0.0010
# Epoch 166/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 5.7157e-04 - mae: 0.0158 - val_loss: 6.1155e-04 - val_mae: 0.0175 - learning_rate: 0.0010
# Epoch 167/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 5.4407e-04 - mae: 0.0154 - val_loss: 5.6547e-04 - val_mae: 0.0179 - learning_rate: 0.0010
# Epoch 168/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 5.0162e-04 - mae: 0.0146 - val_loss: 0.0010 - val_mae: 0.0273 - learning_rate: 5.0000e-04
# Epoch 169/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 4.6063e-04 - mae: 0.0140 - val_loss: 8.6247e-04 - val_mae: 0.0248 - learning_rate: 5.0000e-04
# Epoch 170/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 5.4185e-04 - mae: 0.0153 - val_loss: 5.7687e-04 - val_mae: 0.0185 - learning_rate: 5.0000e-04
# Epoch 171/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 4.6597e-04 - mae: 0.0143 - val_loss: 0.0011 - val_mae: 0.0286 - learning_rate: 5.0000e-04
# Epoch 172/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 5.8088e-04 - mae: 0.0162 - val_loss: 0.0012 - val_mae: 0.0310 - learning_rate: 5.0000e-04
# Epoch 173/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 5.2353e-04 - mae: 0.0153 - val_loss: 7.9581e-04 - val_mae: 0.0238 - learning_rate: 5.0000e-04
# Epoch 174/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 4.7637e-04 - mae: 0.0144 - val_loss: 5.9062e-04 - val_mae: 0.0187 - learning_rate: 5.0000e-04
# Epoch 175/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 5.2346e-04 - mae: 0.0153 - val_loss: 8.9857e-04 - val_mae: 0.0255 - learning_rate: 5.0000e-04
# Epoch 176/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 5.9173e-04 - mae: 0.0164 - val_loss: 7.8779e-04 - val_mae: 0.0235 - learning_rate: 5.0000e-04
# Epoch 177/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 5.8264e-04 - mae: 0.0163 - val_loss: 5.6510e-04 - val_mae: 0.0185 - learning_rate: 5.0000e-04
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Train R²: 0.9714, Test R²: 0.4049
# Train RMSE: 0.2489, Test RMSE: 2.7722

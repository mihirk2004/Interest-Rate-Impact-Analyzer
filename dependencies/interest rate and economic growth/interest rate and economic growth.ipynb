# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import r2_score, mean_squared_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.models import save_model

# Load and preprocess data
df = pd.read_csv('Interest Rate and Economic Growth Rate.csv', parse_dates=['Date'])
df.sort_values('Date', inplace=True)

# Feature engineering: Add moving averages
window_size = 5
df['Interest_MA'] = df['Interest Rate'].rolling(window=window_size).mean()
df['Growth_MA'] = df['Economic Growth Rate'].rolling(window=window_size).mean()
df.dropna(inplace=True)

# Normalize data
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(df[['Interest Rate', 'Economic Growth Rate', 'Interest_MA', 'Growth_MA']])

# Create sequences with multiple features
def create_sequences(data, look_back=10):
    X, y = [], []
    for i in range(len(data)-look_back):
        X.append(data[i:(i+look_back), :2])  # Use both interest rate and growth rate
        y.append(data[i+look_back, 1])       # Predict growth rate
    return np.array(X), np.array(y)

look_back = 10  # Increased window size
X, y = create_sequences(scaled_data, look_back)

# Split into train/test sets
train_size = int(len(X) * 0.8)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# Build enhanced LSTM model
model = Sequential([
    LSTM(128, return_sequences=True, input_shape=(look_back, 2)),
    BatchNormalization(),
    Dropout(0.3),
    LSTM(64, return_sequences=True),
    BatchNormalization(),
    Dropout(0.3),
    LSTM(32),
    BatchNormalization(),
    Dropout(0.2),
    Dense(32, activation='relu', kernel_regularizer='l2'),
    Dense(1)
])

optimizer = Adam(learning_rate=0.001)
model.compile(optimizer=optimizer, loss='mse', metrics=['mae'])

# Add callbacks
callbacks = [
    EarlyStopping(patience=20, restore_best_weights=True),
    ReduceLROnPlateau(factor=0.5, patience=10)
]

# Train model with more epochs
history = model.fit(X_train, y_train,
                    epochs=300,
                    batch_size=64,
                    validation_split=0.2,
                    callbacks=callbacks,
                    verbose=1)

# Save model
save_model(model, 'improved_economic_growth_lstm.h5')

# Make predictions
train_predict = model.predict(X_train)
test_predict = model.predict(X_test)

# Inverse scaling
def inverse_scale(y, scaler, feature_pos=1):
    dummy = np.zeros((len(y), scaled_data.shape[1]))
    dummy[:, feature_pos] = y.reshape(-1)
    return scaler.inverse_transform(dummy)[:, feature_pos]

y_train_actual = inverse_scale(y_train, scaler)
y_test_actual = inverse_scale(y_test, scaler)
train_predict = inverse_scale(train_predict, scaler)
test_predict = inverse_scale(test_predict, scaler)

# Calculate metrics
train_r2 = r2_score(y_train_actual, train_predict)
test_r2 = r2_score(y_test_actual, test_predict)
train_rmse = np.sqrt(mean_squared_error(y_train_actual, train_predict))
test_rmse = np.sqrt(mean_squared_error(y_test_actual, test_predict))

print(f"Train R²: {train_r2:.4f}, Test R²: {test_r2:.4f}")
print(f"Train RMSE: {train_rmse:.4f}, Test RMSE: {test_rmse:.4f}")


# Enhanced visualization
total_samples = len(X)  # This matches y_train_actual + y_test_actual
start_index = look_back  # First valid index after sequence creation

# Create date range for predictions
prediction_dates = df['Date'].iloc[start_index:start_index+total_samples]

plt.figure(figsize=(16, 8))
plt.plot(prediction_dates, np.concatenate([y_train_actual, y_test_actual]), 
         label='Actual Values', color='blue', alpha=0.6)

# Plot predictions
plt.plot(prediction_dates[:len(y_train_actual)], train_predict, 
         label='Train Predictions', color='red', linestyle='--')
plt.plot(prediction_dates[len(y_train_actual):], test_predict,
         label='Test Predictions', color='orange', linestyle='--')

plt.title(f'Economic Growth Rate Predictions\nTest R²: {test_r2:.2f}, Test RMSE: {test_rmse:.2f}')
plt.ylabel('Economic Growth Rate')
plt.xlabel('Date')
plt.legend()
plt.grid(True)
plt.show()

# Feature importance analysis
plt.figure(figsize=(8, 4))
plt.bar(['Interest Rate', 'Economic Growth Rate'],
        np.abs(model.layers[0].get_weights()[0]).mean(axis=1))
plt.title('Input Feature Importance (First LSTM Layer Weights)')
plt.ylabel('Average Weight Magnitude')
plt.show()
# Out:
# C:\Users\Aayush Kuthe\AppData\Local\Temp\ipykernel_24692\2648415725.py:13: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df = pd.read_csv('Interest Rate and Economic Growth Rate.csv', parse_dates=['Date'])
# C:\Users\Aayush Kuthe\AppData\Roaming\Python\Python312\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 9s 71ms/step - loss: 1.8395 - mae: 0.9857 - val_loss: 0.9233 - val_mae: 0.7711 - learning_rate: 0.0010
# Epoch 2/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.5764 - mae: 0.3955 - val_loss: 0.8234 - val_mae: 0.7142 - learning_rate: 0.0010
# Epoch 3/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.4713 - mae: 0.3248 - val_loss: 0.7689 - val_mae: 0.6854 - learning_rate: 0.0010
# Epoch 4/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.3976 - mae: 0.2523 - val_loss: 0.6911 - val_mae: 0.6375 - learning_rate: 0.0010
# Epoch 5/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.3730 - mae: 0.2445 - val_loss: 0.6139 - val_mae: 0.5856 - learning_rate: 0.0010
# Epoch 6/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - loss: 0.3305 - mae: 0.2038 - val_loss: 0.5835 - val_mae: 0.5708 - learning_rate: 0.0010
# Epoch 7/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.3109 - mae: 0.1928 - val_loss: 0.5234 - val_mae: 0.5266 - learning_rate: 0.0010
# Epoch 8/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step - loss: 0.2928 - mae: 0.1818 - val_loss: 0.4503 - val_mae: 0.4647 - learning_rate: 0.0010
# Epoch 9/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step - loss: 0.2750 - mae: 0.1673 - val_loss: 0.4047 - val_mae: 0.4259 - learning_rate: 0.0010
# Epoch 10/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 0.2549 - mae: 0.1530 - val_loss: 0.3675 - val_mae: 0.3927 - learning_rate: 0.0010
# Epoch 11/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step - loss: 0.2441 - mae: 0.1501 - val_loss: 0.3569 - val_mae: 0.3907 - learning_rate: 0.0010
# Epoch 12/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 0.2268 - mae: 0.1400 - val_loss: 0.3238 - val_mae: 0.3584 - learning_rate: 0.0010
# Epoch 13/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - loss: 0.2175 - mae: 0.1400 - val_loss: 0.2670 - val_mae: 0.2857 - learning_rate: 0.0010
# Epoch 14/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.2044 - mae: 0.1299 - val_loss: 0.2406 - val_mae: 0.2497 - learning_rate: 0.0010
# Epoch 15/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - loss: 0.1938 - mae: 0.1257 - val_loss: 0.2256 - val_mae: 0.2411 - learning_rate: 0.0010
# Epoch 16/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step - loss: 0.1814 - mae: 0.1158 - val_loss: 0.1928 - val_mae: 0.1875 - learning_rate: 0.0010
# Epoch 17/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 0.1734 - mae: 0.1140 - val_loss: 0.1773 - val_mae: 0.1637 - learning_rate: 0.0010
# Epoch 18/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 0.1647 - mae: 0.1102 - val_loss: 0.1515 - val_mae: 0.0939 - learning_rate: 0.0010
# Epoch 19/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - loss: 0.1556 - mae: 0.1029 - val_loss: 0.1471 - val_mae: 0.1013 - learning_rate: 0.0010
# Epoch 20/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - loss: 0.1492 - mae: 0.1047 - val_loss: 0.1340 - val_mae: 0.0690 - learning_rate: 0.0010
# Epoch 21/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - loss: 0.1409 - mae: 0.0978 - val_loss: 0.1258 - val_mae: 0.0629 - learning_rate: 0.0010
# Epoch 22/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step - loss: 0.1338 - mae: 0.0948 - val_loss: 0.1190 - val_mae: 0.0553 - learning_rate: 0.0010
# Epoch 23/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - loss: 0.1278 - mae: 0.0940 - val_loss: 0.1130 - val_mae: 0.0544 - learning_rate: 0.0010
# Epoch 24/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 100ms/step - loss: 0.1215 - mae: 0.0923 - val_loss: 0.1066 - val_mae: 0.0437 - learning_rate: 0.0010
# Epoch 25/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step - loss: 0.1157 - mae: 0.0922 - val_loss: 0.1007 - val_mae: 0.0353 - learning_rate: 0.0010
# Epoch 26/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - loss: 0.1090 - mae: 0.0834 - val_loss: 0.0951 - val_mae: 0.0319 - learning_rate: 0.0010
# Epoch 27/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 95ms/step - loss: 0.1034 - mae: 0.0813 - val_loss: 0.0931 - val_mae: 0.0595 - learning_rate: 0.0010
# Epoch 28/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 0.0977 - mae: 0.0776 - val_loss: 0.0867 - val_mae: 0.0379 - learning_rate: 0.0010
# Epoch 29/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 107ms/step - loss: 0.0925 - mae: 0.0750 - val_loss: 0.0832 - val_mae: 0.0462 - learning_rate: 0.0010
# Epoch 30/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - loss: 0.0874 - mae: 0.0706 - val_loss: 0.0779 - val_mae: 0.0364 - learning_rate: 0.0010
# Epoch 31/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - loss: 0.0833 - mae: 0.0704 - val_loss: 0.0760 - val_mae: 0.0523 - learning_rate: 0.0010
# Epoch 32/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - loss: 0.0804 - mae: 0.0757 - val_loss: 0.0715 - val_mae: 0.0452 - learning_rate: 0.0010
# Epoch 33/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 0.0749 - mae: 0.0675 - val_loss: 0.0683 - val_mae: 0.0505 - learning_rate: 0.0010
# Epoch 34/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.0713 - mae: 0.0674 - val_loss: 0.0664 - val_mae: 0.0563 - learning_rate: 0.0010
# Epoch 35/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step - loss: 0.0680 - mae: 0.0689 - val_loss: 0.0600 - val_mae: 0.0347 - learning_rate: 0.0010
# Epoch 36/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 0.0640 - mae: 0.0649 - val_loss: 0.0562 - val_mae: 0.0281 - learning_rate: 0.0010
# Epoch 37/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.0612 - mae: 0.0669 - val_loss: 0.0553 - val_mae: 0.0472 - learning_rate: 0.0010
# Epoch 38/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step - loss: 0.0580 - mae: 0.0633 - val_loss: 0.0556 - val_mae: 0.0641 - learning_rate: 0.0010
# Epoch 39/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - loss: 0.0543 - mae: 0.0597 - val_loss: 0.0483 - val_mae: 0.0364 - learning_rate: 0.0010
# Epoch 40/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 0.0513 - mae: 0.0588 - val_loss: 0.0490 - val_mae: 0.0609 - learning_rate: 0.0010
# Epoch 41/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 97ms/step - loss: 0.0488 - mae: 0.0578 - val_loss: 0.0474 - val_mae: 0.0665 - learning_rate: 0.0010
# Epoch 42/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step - loss: 0.0467 - mae: 0.0602 - val_loss: 0.0415 - val_mae: 0.0406 - learning_rate: 0.0010
# Epoch 43/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - loss: 0.0432 - mae: 0.0538 - val_loss: 0.0396 - val_mae: 0.0413 - learning_rate: 0.0010
# Epoch 44/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0410 - mae: 0.0541 - val_loss: 0.0410 - val_mae: 0.0631 - learning_rate: 0.0010
# Epoch 45/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step - loss: 0.0390 - mae: 0.0538 - val_loss: 0.0367 - val_mae: 0.0493 - learning_rate: 0.0010
# Epoch 46/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - loss: 0.0366 - mae: 0.0517 - val_loss: 0.0354 - val_mae: 0.0526 - learning_rate: 0.0010
# Epoch 47/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - loss: 0.0350 - mae: 0.0532 - val_loss: 0.0376 - val_mae: 0.0694 - learning_rate: 0.0010
# Epoch 48/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0323 - mae: 0.0471 - val_loss: 0.0374 - val_mae: 0.0775 - learning_rate: 0.0010
# Epoch 49/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0308 - mae: 0.0468 - val_loss: 0.0311 - val_mae: 0.0548 - learning_rate: 0.0010
# Epoch 50/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step - loss: 0.0286 - mae: 0.0432 - val_loss: 0.0286 - val_mae: 0.0539 - learning_rate: 0.0010
# Epoch 51/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0273 - mae: 0.0460 - val_loss: 0.0261 - val_mae: 0.0463 - learning_rate: 0.0010
# Epoch 52/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0251 - mae: 0.0404 - val_loss: 0.0240 - val_mae: 0.0411 - learning_rate: 0.0010
# Epoch 53/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0238 - mae: 0.0416 - val_loss: 0.0256 - val_mae: 0.0627 - learning_rate: 0.0010
# Epoch 54/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 0.0233 - mae: 0.0470 - val_loss: 0.0261 - val_mae: 0.0707 - learning_rate: 0.0010
# Epoch 55/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0213 - mae: 0.0416 - val_loss: 0.0220 - val_mae: 0.0547 - learning_rate: 0.0010
# Epoch 56/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.0196 - mae: 0.0370 - val_loss: 0.0216 - val_mae: 0.0589 - learning_rate: 0.0010
# Epoch 57/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0190 - mae: 0.0415 - val_loss: 0.0222 - val_mae: 0.0710 - learning_rate: 0.0010
# Epoch 58/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0176 - mae: 0.0380 - val_loss: 0.0164 - val_mae: 0.0354 - learning_rate: 0.0010
# Epoch 59/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.0166 - mae: 0.0382 - val_loss: 0.0173 - val_mae: 0.0532 - learning_rate: 0.0010
# Epoch 60/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0154 - mae: 0.0355 - val_loss: 0.0162 - val_mae: 0.0518 - learning_rate: 0.0010
# Epoch 61/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0144 - mae: 0.0343 - val_loss: 0.0141 - val_mae: 0.0419 - learning_rate: 0.0010
# Epoch 62/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0137 - mae: 0.0362 - val_loss: 0.0125 - val_mae: 0.0331 - learning_rate: 0.0010
# Epoch 63/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0128 - mae: 0.0337 - val_loss: 0.0125 - val_mae: 0.0403 - learning_rate: 0.0010
# Epoch 64/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0119 - mae: 0.0319 - val_loss: 0.0130 - val_mae: 0.0519 - learning_rate: 0.0010
# Epoch 65/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.0111 - mae: 0.0306 - val_loss: 0.0111 - val_mae: 0.0409 - learning_rate: 0.0010
# Epoch 66/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0105 - mae: 0.0318 - val_loss: 0.0117 - val_mae: 0.0516 - learning_rate: 0.0010
# Epoch 67/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0098 - mae: 0.0311 - val_loss: 0.0104 - val_mae: 0.0448 - learning_rate: 0.0010
# Epoch 68/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.0094 - mae: 0.0328 - val_loss: 0.0083 - val_mae: 0.0278 - learning_rate: 0.0010
# Epoch 69/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0090 - mae: 0.0334 - val_loss: 0.0078 - val_mae: 0.0267 - learning_rate: 0.0010
# Epoch 70/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0081 - mae: 0.0295 - val_loss: 0.0073 - val_mae: 0.0273 - learning_rate: 0.0010
# Epoch 71/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0076 - mae: 0.0290 - val_loss: 0.0071 - val_mae: 0.0310 - learning_rate: 0.0010
# Epoch 72/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0069 - mae: 0.0265 - val_loss: 0.0070 - val_mae: 0.0353 - learning_rate: 0.0010
# Epoch 73/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0067 - mae: 0.0293 - val_loss: 0.0070 - val_mae: 0.0399 - learning_rate: 0.0010
# Epoch 74/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0061 - mae: 0.0268 - val_loss: 0.0073 - val_mae: 0.0452 - learning_rate: 0.0010
# Epoch 75/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0057 - mae: 0.0262 - val_loss: 0.0072 - val_mae: 0.0482 - learning_rate: 0.0010
# Epoch 76/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0054 - mae: 0.0274 - val_loss: 0.0058 - val_mae: 0.0377 - learning_rate: 0.0010
# Epoch 77/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0048 - mae: 0.0232 - val_loss: 0.0050 - val_mae: 0.0309 - learning_rate: 0.0010
# Epoch 78/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0046 - mae: 0.0238 - val_loss: 0.0052 - val_mae: 0.0371 - learning_rate: 0.0010
# Epoch 79/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0043 - mae: 0.0234 - val_loss: 0.0047 - val_mae: 0.0340 - learning_rate: 0.0010
# Epoch 80/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0040 - mae: 0.0230 - val_loss: 0.0041 - val_mae: 0.0288 - learning_rate: 0.0010
# Epoch 81/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.0038 - mae: 0.0231 - val_loss: 0.0041 - val_mae: 0.0316 - learning_rate: 0.0010
# Epoch 82/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0035 - mae: 0.0221 - val_loss: 0.0042 - val_mae: 0.0360 - learning_rate: 0.0010
# Epoch 83/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0034 - mae: 0.0235 - val_loss: 0.0035 - val_mae: 0.0294 - learning_rate: 0.0010
# Epoch 84/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0032 - mae: 0.0227 - val_loss: 0.0031 - val_mae: 0.0277 - learning_rate: 0.0010
# Epoch 85/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.0029 - mae: 0.0219 - val_loss: 0.0033 - val_mae: 0.0327 - learning_rate: 0.0010
# Epoch 86/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0027 - mae: 0.0204 - val_loss: 0.0027 - val_mae: 0.0267 - learning_rate: 0.0010
# Epoch 87/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0027 - mae: 0.0227 - val_loss: 0.0032 - val_mae: 0.0344 - learning_rate: 0.0010
# Epoch 88/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0023 - mae: 0.0194 - val_loss: 0.0030 - val_mae: 0.0325 - learning_rate: 0.0010
# Epoch 89/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0022 - mae: 0.0199 - val_loss: 0.0023 - val_mae: 0.0259 - learning_rate: 0.0010
# Epoch 90/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0021 - mae: 0.0199 - val_loss: 0.0023 - val_mae: 0.0283 - learning_rate: 0.0010
# Epoch 91/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0019 - mae: 0.0199 - val_loss: 0.0027 - val_mae: 0.0353 - learning_rate: 0.0010
# Epoch 92/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0020 - mae: 0.0219 - val_loss: 0.0016 - val_mae: 0.0203 - learning_rate: 0.0010
# Epoch 93/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0018 - mae: 0.0216 - val_loss: 0.0015 - val_mae: 0.0184 - learning_rate: 0.0010
# Epoch 94/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0017 - mae: 0.0201 - val_loss: 0.0015 - val_mae: 0.0203 - learning_rate: 0.0010
# Epoch 95/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0016 - mae: 0.0196 - val_loss: 0.0016 - val_mae: 0.0242 - learning_rate: 0.0010
# Epoch 96/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0014 - mae: 0.0185 - val_loss: 0.0023 - val_mae: 0.0350 - learning_rate: 0.0010
# Epoch 97/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0014 - mae: 0.0198 - val_loss: 0.0018 - val_mae: 0.0300 - learning_rate: 0.0010
# Epoch 98/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0013 - mae: 0.0190 - val_loss: 0.0012 - val_mae: 0.0185 - learning_rate: 0.0010
# Epoch 99/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0013 - mae: 0.0187 - val_loss: 0.0011 - val_mae: 0.0188 - learning_rate: 0.0010
# Epoch 100/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0012 - mae: 0.0183 - val_loss: 0.0012 - val_mae: 0.0213 - learning_rate: 0.0010
# Epoch 101/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0011 - mae: 0.0178 - val_loss: 0.0018 - val_mae: 0.0314 - learning_rate: 0.0010
# Epoch 102/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0011 - mae: 0.0184 - val_loss: 0.0017 - val_mae: 0.0285 - learning_rate: 0.0010
# Epoch 103/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.0011 - mae: 0.0192 - val_loss: 0.0018 - val_mae: 0.0321 - learning_rate: 0.0010
# Epoch 104/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 9.3123e-04 - mae: 0.0168 - val_loss: 0.0015 - val_mae: 0.0283 - learning_rate: 0.0010
# Epoch 105/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 9.1552e-04 - mae: 0.0167 - val_loss: 0.0020 - val_mae: 0.0359 - learning_rate: 0.0010
# Epoch 106/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 0.0010 - mae: 0.0192 - val_loss: 0.0011 - val_mae: 0.0221 - learning_rate: 0.0010
# Epoch 107/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 8.7785e-04 - mae: 0.0171 - val_loss: 0.0015 - val_mae: 0.0300 - learning_rate: 0.0010
# Epoch 108/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - loss: 8.1940e-04 - mae: 0.0168 - val_loss: 0.0014 - val_mae: 0.0290 - learning_rate: 0.0010
# Epoch 109/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 8.6034e-04 - mae: 0.0183 - val_loss: 0.0010 - val_mae: 0.0217 - learning_rate: 0.0010
# Epoch 110/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 8.5953e-04 - mae: 0.0186 - val_loss: 8.9395e-04 - val_mae: 0.0180 - learning_rate: 0.0010
# Epoch 111/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 7.6057e-04 - mae: 0.0165 - val_loss: 0.0015 - val_mae: 0.0305 - learning_rate: 0.0010
# Epoch 112/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 8.4280e-04 - mae: 0.0183 - val_loss: 0.0014 - val_mae: 0.0293 - learning_rate: 0.0010
# Epoch 113/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 7.9542e-04 - mae: 0.0179 - val_loss: 0.0013 - val_mae: 0.0291 - learning_rate: 0.0010
# Epoch 114/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 7.8964e-04 - mae: 0.0181 - val_loss: 7.9666e-04 - val_mae: 0.0197 - learning_rate: 0.0010
# Epoch 115/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 8.0526e-04 - mae: 0.0184 - val_loss: 8.8619e-04 - val_mae: 0.0208 - learning_rate: 0.0010
# Epoch 116/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 7.7931e-04 - mae: 0.0183 - val_loss: 0.0011 - val_mae: 0.0259 - learning_rate: 0.0010
# Epoch 117/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 7.8552e-04 - mae: 0.0186 - val_loss: 7.2508e-04 - val_mae: 0.0192 - learning_rate: 0.0010
# Epoch 118/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 6.9656e-04 - mae: 0.0169 - val_loss: 5.8682e-04 - val_mae: 0.0165 - learning_rate: 0.0010
# Epoch 119/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 8.8828e-04 - mae: 0.0204 - val_loss: 0.0013 - val_mae: 0.0316 - learning_rate: 0.0010
# Epoch 120/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 6.7470e-04 - mae: 0.0171 - val_loss: 6.4799e-04 - val_mae: 0.0179 - learning_rate: 0.0010
# Epoch 121/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 7.8448e-04 - mae: 0.0191 - val_loss: 7.6803e-04 - val_mae: 0.0217 - learning_rate: 0.0010
# Epoch 122/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 6.0293e-04 - mae: 0.0161 - val_loss: 6.1404e-04 - val_mae: 0.0158 - learning_rate: 0.0010
# Epoch 123/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 7.1533e-04 - mae: 0.0180 - val_loss: 8.3463e-04 - val_mae: 0.0223 - learning_rate: 0.0010
# Epoch 124/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 7.1149e-04 - mae: 0.0175 - val_loss: 5.2456e-04 - val_mae: 0.0138 - learning_rate: 0.0010
# Epoch 125/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 6.4040e-04 - mae: 0.0171 - val_loss: 0.0019 - val_mae: 0.0365 - learning_rate: 0.0010
# Epoch 126/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 6.6692e-04 - mae: 0.0177 - val_loss: 6.8296e-04 - val_mae: 0.0200 - learning_rate: 0.0010
# Epoch 127/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 5.6734e-04 - mae: 0.0160 - val_loss: 0.0010 - val_mae: 0.0270 - learning_rate: 0.0010
# Epoch 128/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 5.9603e-04 - mae: 0.0165 - val_loss: 9.5303e-04 - val_mae: 0.0260 - learning_rate: 0.0010
# Epoch 129/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 5.7484e-04 - mae: 0.0159 - val_loss: 0.0011 - val_mae: 0.0289 - learning_rate: 5.0000e-04
# Epoch 130/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 5.9848e-04 - mae: 0.0165 - val_loss: 6.5002e-04 - val_mae: 0.0202 - learning_rate: 5.0000e-04
# Epoch 131/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 6.4452e-04 - mae: 0.0170 - val_loss: 7.2818e-04 - val_mae: 0.0218 - learning_rate: 5.0000e-04
# Epoch 132/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 5.6573e-04 - mae: 0.0160 - val_loss: 8.5461e-04 - val_mae: 0.0242 - learning_rate: 5.0000e-04
# Epoch 133/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 5.6073e-04 - mae: 0.0160 - val_loss: 7.2761e-04 - val_mae: 0.0222 - learning_rate: 5.0000e-04
# Epoch 134/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 5.5912e-04 - mae: 0.0162 - val_loss: 7.7953e-04 - val_mae: 0.0233 - learning_rate: 5.0000e-04
# Epoch 135/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 5.3590e-04 - mae: 0.0152 - val_loss: 8.7984e-04 - val_mae: 0.0251 - learning_rate: 5.0000e-04
# Epoch 136/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 6.2836e-04 - mae: 0.0165 - val_loss: 6.6248e-04 - val_mae: 0.0207 - learning_rate: 5.0000e-04
# Epoch 137/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 5.2347e-04 - mae: 0.0151 - val_loss: 0.0013 - val_mae: 0.0321 - learning_rate: 5.0000e-04
# Epoch 138/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 5.1959e-04 - mae: 0.0150 - val_loss: 9.1293e-04 - val_mae: 0.0257 - learning_rate: 5.0000e-04
# Epoch 139/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 4.7737e-04 - mae: 0.0142 - val_loss: 0.0011 - val_mae: 0.0286 - learning_rate: 2.5000e-04
# Epoch 140/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 5.0871e-04 - mae: 0.0147 - val_loss: 8.1151e-04 - val_mae: 0.0239 - learning_rate: 2.5000e-04
# Epoch 141/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 4.6900e-04 - mae: 0.0144 - val_loss: 9.5905e-04 - val_mae: 0.0264 - learning_rate: 2.5000e-04
# Epoch 142/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 5.0619e-04 - mae: 0.0144 - val_loss: 7.7307e-04 - val_mae: 0.0229 - learning_rate: 2.5000e-04
# Epoch 143/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 5.6906e-04 - mae: 0.0156 - val_loss: 8.3199e-04 - val_mae: 0.0243 - learning_rate: 2.5000e-04
# Epoch 144/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 4.3500e-04 - mae: 0.0136 - val_loss: 0.0010 - val_mae: 0.0278 - learning_rate: 2.5000e-04
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Train R²: 0.9617, Test R²: 0.3849
# Train RMSE: 0.2880, Test RMSE: 2.8183

# %%
import pandas as pd
import numpy as np
import joblib 
from sklearn.preprocessing import MinMaxScaler

df = pd.read_csv('Interest Rate and Economic Growth Rate.csv', parse_dates=['Date'])
df.sort_values('Date', inplace=True)

# Feature engineering: Add moving averages
window_size = 5
df['Interest_MA'] = df['Interest Rate'].rolling(window=window_size).mean()
df['Growth_MA'] = df['Economic Growth Rate'].rolling(window=window_size).mean()
df.dropna(inplace=True)

# Normalize data
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(df[['Interest Rate', 'Economic Growth Rate', 'Interest_MA', 'Growth_MA']])

# Create sequences with multiple features
def create_sequences(data, look_back=10):
    X, y = [], []
    for i in range(len(data)-look_back):
        X.append(data[i:(i+look_back), :2])  # Use both interest rate and growth rate
        y.append(data[i+look_back, 1])       # Predict growth rate
    return np.array(X), np.array(y)

look_back = 10  # Increased window size
X, y = create_sequences(scaled_data, look_back)

joblib.dump(scaler, 'scaler.save')  # During training
scaler = joblib.load('scaler.save')  # In the Streamlit app
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_11916\3455683649.py:6: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df = pd.read_csv('Interest Rate and Economic Growth Rate.csv', parse_dates=['Date'])

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import r2_score, mean_squared_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.models import save_model
from tensorflow.keras.metrics import MeanSquaredError

# Load and preprocess data
df = pd.read_csv('Interest Rate and Economic Growth Rate.csv', parse_dates=['Date'])
df.sort_values('Date', inplace=True)

# Feature engineering: Add moving averages
window_size = 5
df['Interest_MA'] = df['Interest Rate'].rolling(window=window_size).mean()
df['Growth_MA'] = df['Economic Growth Rate'].rolling(window=window_size).mean()
df.dropna(inplace=True)

# Normalize data
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(df[['Interest Rate', 'Economic Growth Rate', 'Interest_MA', 'Growth_MA']])

# Create sequences with multiple features
def create_sequences(data, look_back=10):
    X, y = [], []
    for i in range(len(data)-look_back):
        X.append(data[i:(i+look_back), :2])  # Use both interest rate and growth rate
        y.append(data[i+look_back, 1])       # Predict growth rate
    return np.array(X), np.array(y)

look_back = 10  # Increased window size
X, y = create_sequences(scaled_data, look_back)

# Split into train/test sets
train_size = int(len(X) * 0.8)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# Build enhanced LSTM model
model = Sequential([
    LSTM(128, return_sequences=True, input_shape=(look_back, 2)),
    BatchNormalization(),
    Dropout(0.3),
    LSTM(64, return_sequences=True),
    BatchNormalization(),
    Dropout(0.3),
    LSTM(32),
    BatchNormalization(),
    Dropout(0.2),
    Dense(32, activation='relu', kernel_regularizer='l2'),
    Dense(1)
])

optimizer = Adam(learning_rate=0.001)
# model.compile(optimizer=optimizer, loss='mse', metrics=['mae'])

model.compile(optimizer=optimizer,
              loss=MeanSquaredError(),  # Explicit class
              metrics=[MeanSquaredError(name='mse')])

# Add callbacks
callbacks = [
    EarlyStopping(patience=20, restore_best_weights=True),
    ReduceLROnPlateau(factor=0.5, patience=10)
]

# Train model with more epochs
history = model.fit(X_train, y_train,
                    epochs=300,
                    batch_size=64,
                    validation_split=0.2,
                    callbacks=callbacks,
                    verbose=1)

# Save model
# save_model(model, 'improved_economic_growth_lstm.h5')
# In your training code:
# model.compile(optimizer=optimizer,
#               loss=MeanSquaredError(),  # Explicit class
#               metrics=[MeanSquaredError()])  # Explicit class
model.save('trial_model.h5', save_format='h5')

# Make predictions
train_predict = model.predict(X_train)
test_predict = model.predict(X_test)

# Inverse scaling
def inverse_scale(y, scaler, feature_pos=1):
    dummy = np.zeros((len(y), scaled_data.shape[1]))
    dummy[:, feature_pos] = y.reshape(-1)
    return scaler.inverse_transform(dummy)[:, feature_pos]

y_train_actual = inverse_scale(y_train, scaler)
y_test_actual = inverse_scale(y_test, scaler)
train_predict = inverse_scale(train_predict, scaler)
test_predict = inverse_scale(test_predict, scaler)

# Calculate metrics
train_r2 = r2_score(y_train_actual, train_predict)
test_r2 = r2_score(y_test_actual, test_predict)
train_rmse = np.sqrt(mean_squared_error(y_train_actual, train_predict))
test_rmse = np.sqrt(mean_squared_error(y_test_actual, test_predict))

print(f"Train R²: {train_r2:.4f}, Test R²: {test_r2:.4f}")
print(f"Train RMSE: {train_rmse:.4f}, Test RMSE: {test_rmse:.4f}")


# Enhanced visualization
total_samples = len(X)  # This matches y_train_actual + y_test_actual
start_index = look_back  # First valid index after sequence creation

# Create date range for predictions
prediction_dates = df['Date'].iloc[start_index:start_index+total_samples]

plt.figure(figsize=(16, 8))
plt.plot(prediction_dates, np.concatenate([y_train_actual, y_test_actual]), 
         label='Actual Values', color='blue', alpha=0.6)

# Plot predictions
plt.plot(prediction_dates[:len(y_train_actual)], train_predict, 
         label='Train Predictions', color='red', linestyle='--')
plt.plot(prediction_dates[len(y_train_actual):], test_predict,
         label='Test Predictions', color='orange', linestyle='--')

plt.title(f'Economic Growth Rate Predictions\nTest R²: {test_r2:.2f}, Test RMSE: {test_rmse:.2f}')
plt.ylabel('Economic Growth Rate')
plt.xlabel('Date')
plt.legend()
plt.grid(True)
plt.show()

# Feature importance analysis
plt.figure(figsize=(8, 4))
plt.bar(['Interest Rate', 'Economic Growth Rate'],
        np.abs(model.layers[0].get_weights()[0]).mean(axis=1))
plt.title('Input Feature Importance (First LSTM Layer Weights)')
plt.ylabel('Average Weight Magnitude')
plt.show()
# Out:
# Epoch 1/300
# C:\Users\Admin\AppData\Local\Temp\ipykernel_11916\1040835809.py:14: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df = pd.read_csv('Interest Rate and Economic Growth Rate.csv', parse_dates=['Date'])
# c:\Users\Admin\Documents\Mihir Codes\Sem 4\AI Assignments\AI PBL\aipblenv\lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# c:\Users\Admin\Documents\Mihir Codes\Sem 4\AI Assignments\AI PBL\aipblenv\lib\site-packages\keras\src\optimizers\base_optimizer.py:774: UserWarning: Gradients do not exist for variables ['sequential_2/lstm_6/lstm_cell/kernel', 'sequential_2/lstm_6/lstm_cell/recurrent_kernel', 'sequential_2/lstm_6/lstm_cell/bias', 'sequential_2/batch_normalization_6/gamma', 'sequential_2/batch_normalization_6/beta', 'sequential_2/lstm_7/lstm_cell/kernel', 'sequential_2/lstm_7/lstm_cell/recurrent_kernel', 'sequential_2/lstm_7/lstm_cell/bias', 'sequential_2/batch_normalization_7/gamma', 'sequential_2/batch_normalization_7/beta', 'sequential_2/lstm_8/lstm_cell/kernel', 'sequential_2/lstm_8/lstm_cell/recurrent_kernel', 'sequential_2/lstm_8/lstm_cell/bias', 'sequential_2/batch_normalization_8/gamma', 'sequential_2/batch_normalization_8/beta', 'sequential_2/dense_4/bias', 'sequential_2/dense_5/kernel', 'sequential_2/dense_5/bias'] when minimizing the loss. If using `model.compile()`, did you forget to provide a `loss` argument?
#   warnings.warn(
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 57ms/step - loss: 1.0607 - mse: 0.7549 - val_loss: 1.0057 - val_mse: 0.6857 - learning_rate: 0.0010
# Epoch 2/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.9803 - mse: 0.6698 - val_loss: 0.9065 - val_mse: 0.7035 - learning_rate: 0.0010
# Epoch 3/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.8826 - mse: 0.5445 - val_loss: 0.8185 - val_mse: 0.7107 - learning_rate: 0.0010
# Epoch 4/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.8008 - mse: 0.4862 - val_loss: 0.7516 - val_mse: 0.7161 - learning_rate: 0.0010
# Epoch 5/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.7370 - mse: 0.4334 - val_loss: 0.6977 - val_mse: 0.7187 - learning_rate: 0.0010
# Epoch 6/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.6852 - mse: 0.3845 - val_loss: 0.6517 - val_mse: 0.7207 - learning_rate: 0.0010
# Epoch 7/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.6423 - mse: 0.3793 - val_loss: 0.6160 - val_mse: 0.7190 - learning_rate: 0.0010
# Epoch 8/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.6090 - mse: 0.3788 - val_loss: 0.5866 - val_mse: 0.7169 - learning_rate: 0.0010
# Epoch 9/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.5811 - mse: 0.3765 - val_loss: 0.5652 - val_mse: 0.7076 - learning_rate: 0.0010
# Epoch 10/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.5611 - mse: 0.3850 - val_loss: 0.5483 - val_mse: 0.6932 - learning_rate: 0.0010
# Epoch 11/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.5454 - mse: 0.3984 - val_loss: 0.5360 - val_mse: 0.6780 - learning_rate: 0.0010
# Epoch 12/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.5340 - mse: 0.4158 - val_loss: 0.5268 - val_mse: 0.6617 - learning_rate: 0.0010
# Epoch 13/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.5257 - mse: 0.4449 - val_loss: 0.5211 - val_mse: 0.6436 - learning_rate: 0.0010
# Epoch 14/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.5204 - mse: 0.4578 - val_loss: 0.5171 - val_mse: 0.6264 - learning_rate: 0.0010
# Epoch 15/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.5170 - mse: 0.4817 - val_loss: 0.5150 - val_mse: 0.6140 - learning_rate: 0.0010
# Epoch 16/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.5151 - mse: 0.4975 - val_loss: 0.5140 - val_mse: 0.6030 - learning_rate: 0.0010
# Epoch 17/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.5146 - mse: 0.5207 - val_loss: 0.5141 - val_mse: 0.5958 - learning_rate: 0.0010
# Epoch 18/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.5148 - mse: 0.5275 - val_loss: 0.5148 - val_mse: 0.5912 - learning_rate: 0.0010
# Epoch 19/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.5156 - mse: 0.5428 - val_loss: 0.5161 - val_mse: 0.5922 - learning_rate: 0.0010
# Epoch 20/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.5169 - mse: 0.5506 - val_loss: 0.5180 - val_mse: 0.5972 - learning_rate: 0.0010
# Epoch 21/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.5190 - mse: 0.5632 - val_loss: 0.5203 - val_mse: 0.6048 - learning_rate: 0.0010
# Epoch 22/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.5214 - mse: 0.5784 - val_loss: 0.5229 - val_mse: 0.6152 - learning_rate: 0.0010
# Epoch 23/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.5239 - mse: 0.5775 - val_loss: 0.5258 - val_mse: 0.6268 - learning_rate: 0.0010
# Epoch 24/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.5270 - mse: 0.5968 - val_loss: 0.5288 - val_mse: 0.6383 - learning_rate: 0.0010
# Epoch 25/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.5300 - mse: 0.5973 - val_loss: 0.5320 - val_mse: 0.6493 - learning_rate: 0.0010
# Epoch 26/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.5331 - mse: 0.6018 - val_loss: 0.5351 - val_mse: 0.6594 - learning_rate: 0.0010
# Epoch 27/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.5364 - mse: 0.6158 - val_loss: 0.5382 - val_mse: 0.6640 - learning_rate: 5.0000e-04
# Epoch 28/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.5394 - mse: 0.6109 - val_loss: 0.5412 - val_mse: 0.6685 - learning_rate: 5.0000e-04
# Epoch 29/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.5423 - mse: 0.6150 - val_loss: 0.5441 - val_mse: 0.6726 - learning_rate: 5.0000e-04
# Epoch 30/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.5452 - mse: 0.6178 - val_loss: 0.5469 - val_mse: 0.6766 - learning_rate: 5.0000e-04
# Epoch 31/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.5479 - mse: 0.6136 - val_loss: 0.5496 - val_mse: 0.6803 - learning_rate: 5.0000e-04
# Epoch 32/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.5505 - mse: 0.6211 - val_loss: 0.5521 - val_mse: 0.6835 - learning_rate: 5.0000e-04
# Epoch 33/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.5531 - mse: 0.6236 - val_loss: 0.5546 - val_mse: 0.6868 - learning_rate: 5.0000e-04
# Epoch 34/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.5554 - mse: 0.6186 - val_loss: 0.5569 - val_mse: 0.6894 - learning_rate: 5.0000e-04
# Epoch 35/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.5578 - mse: 0.6201 - val_loss: 0.5592 - val_mse: 0.6918 - learning_rate: 5.0000e-04
# Epoch 36/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.5600 - mse: 0.6199 - val_loss: 0.5614 - val_mse: 0.6942 - learning_rate: 5.0000e-04
# WARNING:absl:The `save_format` argument is deprecated in Keras 3. We recommend removing this argument as it can be inferred from the file path. Received: save_format=h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Train R²: -64.7940, Test R²: -9.5132
# Train RMSE: 11.9298, Test RMSE: 11.6519

# %%
# During training:
from joblib import dump
dump(scaler, 'scaler.joblib')
# Out:
# ['scaler.joblib']

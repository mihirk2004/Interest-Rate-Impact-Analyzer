# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout

# Load and preprocess data
df = pd.read_csv('interest rate.csv', parse_dates=['Date'])
df = df.sort_values('Date').set_index('Date')

# Resample to monthly data and handle missing values
df_monthly = df.resample('M').mean().interpolate()

# Normalize data
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(df_monthly)

# Create sequences for LSTM
def create_sequences(data, seq_length):
    X, y = [], []
    for i in range(len(data)-seq_length-1):
        X.append(data[i:(i+seq_length), 0])
        y.append(data[i+seq_length, 0])
    return np.array(X), np.array(y)

SEQ_LENGTH = 12  # Use 12 months to predict next month
X, y = create_sequences(scaled_data, SEQ_LENGTH)

# Reshape for LSTM input [samples, time steps, features]
X = np.reshape(X, (X.shape[0], X.shape[1], 1))

# Split data (80-20 split)
split = int(0.8 * len(X))
X_train, X_test = X[:split], X[split:]
y_train, y_test = y[:split], y[split:]

# Build LSTM model
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(X_train.shape[1], 1)))
model.add(Dropout(0.2))
model.add(LSTM(units=50, return_sequences=False))
model.add(Dropout(0.2))
model.add(Dense(units=1))

model.compile(optimizer='adam', loss='mean_squared_error')

# Train model
history = model.fit(X_train, y_train, 
                    epochs=50, 
                    batch_size=32,
                    validation_data=(X_test, y_test),
                    verbose=1)

# Plot training loss
plt.plot(history.history['loss'], label='Training loss')
plt.plot(history.history['val_loss'], label='Validation loss')
plt.legend()
plt.show()

# Make predictions
train_predict = model.predict(X_train)
test_predict = model.predict(X_test)

# Inverse transform predictions
train_predict = scaler.inverse_transform(train_predict)
y_train_actual = scaler.inverse_transform([y_train])
test_predict = scaler.inverse_transform(test_predict)
y_test_actual = scaler.inverse_transform([y_test])

# Plot results
plt.figure(figsize=(15,6))
plt.plot(df_monthly.index, df_monthly['Average'], label='Actual Rates')
plt.plot(df_monthly.index[SEQ_LENGTH:split+SEQ_LENGTH], train_predict, label='Training Predictions')
test_start = split + SEQ_LENGTH
test_end = test_start + len(X_test)
plt.plot(df_monthly.index[test_start:test_end], test_predict, label='Testing Predictions')
plt.legend()
plt.show()

# Predict future 5 years (60 months)
def predict_future(model, last_sequence, future_steps):
    predictions = []
    current_sequence = last_sequence.copy()
    
    for _ in range(future_steps):
        next_pred = model.predict(current_sequence.reshape(1, SEQ_LENGTH, 1))
        predictions.append(next_pred[0,0])
        current_sequence = np.append(current_sequence[1:], next_pred)
    
    return predictions

last_sequence = scaled_data[-SEQ_LENGTH:]
future_predictions = predict_future(model, last_sequence, 60)
future_predictions = scaler.inverse_transform([future_predictions])[0]

# Create future dates
last_date = df_monthly.index[-1]
future_dates = pd.date_range(start=last_date, periods=60+1, freq='M')[1:]

# Plot future predictions
plt.figure(figsize=(15,6))
plt.plot(df_monthly.index, df_monthly['Average'], label='Historical Rates')
plt.plot(future_dates, future_predictions, label='5-Year Forecast', linestyle='--')
plt.title('Interest Rate Forecast')
plt.xlabel('Date')
plt.ylabel('Interest Rate')
plt.legend()
plt.show()
# Out:
# C:\Users\Aayush Kuthe\AppData\Local\Temp\ipykernel_22548\3103508753.py:13: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df_monthly = df.resample('M').mean().interpolate()
# C:\Users\Aayush Kuthe\AppData\Roaming\Python\Python312\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 162ms/step - loss: 0.1137 - val_loss: 0.0129
# Epoch 2/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0148 - val_loss: 0.0153
# Epoch 3/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0123 - val_loss: 0.0114
# Epoch 4/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0122 - val_loss: 0.0110
# Epoch 5/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0109 - val_loss: 0.0115
# Epoch 6/50
# ...

# %%
# ... (Previous code until future predictions)

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout

# Load and preprocess data
df = pd.read_csv('interest rate.csv', parse_dates=['Date'])
df = df.sort_values('Date').set_index('Date')

# Resample to monthly data and handle missing values
df_monthly = df.resample('M').mean().interpolate()

# Normalize data
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(df_monthly)

# Create sequences for LSTM
def create_sequences(data, seq_length):
    X, y = [], []
    for i in range(len(data)-seq_length-1):
        X.append(data[i:(i+seq_length), 0])
        y.append(data[i+seq_length, 0])
    return np.array(X), np.array(y)

SEQ_LENGTH = 12  # Use 12 months to predict next month
X, y = create_sequences(scaled_data, SEQ_LENGTH)

# Reshape for LSTM input [samples, time steps, features]
X = np.reshape(X, (X.shape[0], X.shape[1], 1))

# Split data (80-20 split)
split = int(0.8 * len(X))
X_train, X_test = X[:split], X[split:]
y_train, y_test = y[:split], y[split:]

# Build LSTM model
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(X_train.shape[1], 1)))
model.add(Dropout(0.2))
model.add(LSTM(units=50, return_sequences=False))
model.add(Dropout(0.2))
model.add(Dense(units=1))

model.compile(optimizer='adam', loss='mean_squared_error')

# Train model
history = model.fit(X_train, y_train, 
                    epochs=50, 
                    batch_size=32,
                    validation_data=(X_test, y_test),
                    verbose=1)

# Plot training loss
plt.plot(history.history['loss'], label='Training loss')
plt.plot(history.history['val_loss'], label='Validation loss')
plt.legend()
plt.show()

# Make predictions
train_predict = model.predict(X_train)
test_predict = model.predict(X_test)

# Inverse transform predictions
train_predict = scaler.inverse_transform(train_predict)
y_train_actual = scaler.inverse_transform([y_train])
test_predict = scaler.inverse_transform(test_predict)
y_test_actual = scaler.inverse_transform([y_test])

# Plot results
plt.figure(figsize=(15,6))
plt.plot(df_monthly.index, df_monthly['Average'], label='Actual Rates')
plt.plot(df_monthly.index[SEQ_LENGTH:split+SEQ_LENGTH], train_predict, label='Training Predictions')
test_start = split + SEQ_LENGTH
test_end = test_start + len(X_test)
plt.plot(df_monthly.index[test_start:test_end], test_predict, label='Testing Predictions')
plt.legend()
plt.show()

# Predict future 5 years (60 months)
def predict_future(model, last_sequence, future_steps):
    predictions = []
    current_sequence = last_sequence.copy()
    
    for _ in range(future_steps):
        next_pred = model.predict(current_sequence.reshape(1, SEQ_LENGTH, 1))
        predictions.append(next_pred[0,0])
        current_sequence = np.append(current_sequence[1:], next_pred)
    
    return predictions

last_sequence = scaled_data[-SEQ_LENGTH:]
future_predictions = predict_future(model, last_sequence, 60)
future_predictions = scaler.inverse_transform([future_predictions])[0]

# Create future dates (monthly)
last_date = df_monthly.index[-1]
future_dates_monthly = pd.date_range(start=last_date, periods=60+1, freq='M')[1:]

# --- NEW: Aggregate predictions year-by-year ---
# Create DataFrame for future predictions
future_df = pd.DataFrame({
    'Date': future_dates_monthly,
    'Predicted_Rate': future_predictions
})
future_df.set_index('Date', inplace=True)

# Resample to yearly (using December values)
yearly_df = future_df.resample('Y').last()  # Or .mean() for yearly averages
yearly_df.index = yearly_df.index.year  # Keep only the year
yearly_df = yearly_df.reset_index()
yearly_df.columns = ['Year', 'Predicted_Interest_Rate']

# Save yearly predictions to CSV
yearly_df.to_csv('yearly_interest_rate_predictions.csv', index=False)

# --- Plot with yearly labels ---
plt.figure(figsize=(15,6))
plt.plot(df_monthly.index, df_monthly['Average'], label='Historical Rates')
plt.plot(future_df.index, future_df['Predicted_Rate'], '--', label='Monthly Forecast')

# Add yearly markers
plt.scatter(
    yearly_df['Year'].map(lambda x: pd.Timestamp(f"{x}-12-31")),  # Fake dates for plotting
    yearly_df['Predicted_Interest_Rate'],
    color='red',
    label='Yearly Predictions',
    zorder=10
)

# Annotate yearly values
for year, rate in zip(yearly_df['Year'], yearly_df['Predicted_Interest_Rate']):
    plt.text(
        pd.Timestamp(f"{year}-06-30"),  # Place text in middle of the year
        rate + 0.1,  # Offset to avoid overlapping with points
        f"{rate:.2f}%",
        ha='center'
    )

plt.title('Interest Rate Forecast (2024-2028)')
plt.xlabel('Year')
plt.ylabel('Interest Rate (%)')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Epoch 1/50
# C:\Users\Aayush Kuthe\AppData\Local\Temp\ipykernel_22548\1330226925.py:15: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df_monthly = df.resample('M').mean().interpolate()
# C:\Users\Aayush Kuthe\AppData\Roaming\Python\Python312\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 97ms/step - loss: 0.0726 - val_loss: 0.0153
# Epoch 2/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0223 - val_loss: 0.0104
# Epoch 3/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0123 - val_loss: 0.0101
# Epoch 4/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0133 - val_loss: 0.0102
# Epoch 5/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0089 - val_loss: 0.0092
# Epoch 6/50
# ...

# %%
print("hello")
# Out:
# hello

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping
from datetime import datetime, timedelta

# Load the dataset
df = pd.read_csv('interest rate.csv', parse_dates=['Date'])
df = df.sort_values('Date').reset_index(drop=True)

# Data preprocessing
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(df[['Average']].values)

# Create sequences for LSTM
def create_sequences(data, seq_length):
    X, y = [], []
    for i in range(len(data)-seq_length-1):
        X.append(data[i:(i+seq_length), 0])
        y.append(data[i+seq_length, 0])
    return np.array(X), np.array(y)

# Parameters
SEQ_LENGTH = 60  # Look back period (2 months)
TEST_SIZE = 0.2  # 20% for testing
EPOCHS = 100
BATCH_SIZE = 32

# Create sequences
X, y = create_sequences(scaled_data, SEQ_LENGTH)

# Split into train and test
train_size = int(len(X) * (1 - TEST_SIZE))
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# Reshape for LSTM [samples, time steps, features]
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# Build LSTM model
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(X_train.shape[1], 1)))
model.add(Dropout(0.2))
model.add(LSTM(50, return_sequences=False))
model.add(Dropout(0.2))
model.add(Dense(1))

model.compile(optimizer='adam', loss='mean_squared_error')

# Train the model
early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
history = model.fit(
    X_train, y_train, 
    epochs=EPOCHS, 
    batch_size=BATCH_SIZE, 
    validation_data=(X_test, y_test), 
    callbacks=[early_stop],
    verbose=1
)

# Plot training history
plt.figure(figsize=(12, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Make predictions on test data
test_predict = model.predict(X_test)
test_predict = scaler.inverse_transform(test_predict)
y_test_actual = scaler.inverse_transform(y_test.reshape(-1, 1))

# Calculate RMSE
rmse = np.sqrt(mean_squared_error(y_test_actual, test_predict))
print(f'Test RMSE: {rmse:.4f}')

# Plot test predictions vs actual
plt.figure(figsize=(12, 6))
plt.plot(df['Date'][-len(y_test_actual):], y_test_actual, label='Actual')
plt.plot(df['Date'][-len(test_predict):], test_predict, label='Predicted')
plt.title('Interest Rate: Actual vs Predicted')
plt.xlabel('Date')
plt.ylabel('Interest Rate')
plt.legend()
plt.show()

# Function to predict future values
def predict_future(model, last_sequence, future_steps, scaler):
    predictions = []
    current_sequence = last_sequence.copy()
    
    for _ in range(future_steps):
        # Get prediction
        current_pred = model.predict(current_sequence.reshape(1, SEQ_LENGTH, 1))
        predictions.append(current_pred[0, 0])
        
        # Update sequence
        current_sequence = np.roll(current_sequence, -1)
        current_sequence[-1] = current_pred
        
    # Inverse transform predictions
    predictions = scaler.inverse_transform(np.array(predictions).reshape(-1, 1))
    return predictions

# Get last sequence from data
last_sequence = scaled_data[-SEQ_LENGTH:]

# Predict next 5 years (assuming daily data, but we'll adjust for business days)
business_days_per_year = 252
future_steps = 5 * business_days_per_year  # Approximate 5 years of business days

future_predictions = predict_future(model, last_sequence, future_steps, scaler)

# Create future dates
last_date = df['Date'].iloc[-1]
future_dates = pd.date_range(start=last_date + timedelta(days=1), periods=future_steps, freq='B')  # Business days

# Plot future predictions
plt.figure(figsize=(14, 7))
plt.plot(df['Date'], df['Average'], label='Historical Data')
plt.plot(future_dates, future_predictions, label='5-Year Forecast', color='red')
plt.title('Interest Rate Forecast for Next 5 Years')
plt.xlabel('Date')
plt.ylabel('Interest Rate')
plt.legend()
plt.grid(True)
plt.show()

# Create a DataFrame with the predictions
forecast_df = pd.DataFrame({
    'Date': future_dates,
    'Predicted_Interest_Rate': future_predictions.flatten()
})

# Print some forecast values
print("\nSample of 5-Year Forecast:")
print(forecast_df.head())
print(forecast_df.tail())
# Out:
# c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 8s 67ms/step - loss: 0.0245 - val_loss: 8.0585e-04
# Epoch 2/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 3s 50ms/step - loss: 0.0017 - val_loss: 7.0124e-04
# Epoch 3/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.0016 - val_loss: 6.1700e-04
# Epoch 4/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 3s 57ms/step - loss: 0.0014 - val_loss: 5.4004e-04
# Epoch 5/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - loss: 0.0014 - val_loss: 6.6995e-04
# Epoch 6/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.0012 - val_loss: 7.8360e-04
# Epoch 7/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 0.0014 - val_loss: 5.5809e-04
# Epoch 8/100
# ...
